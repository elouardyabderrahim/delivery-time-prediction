# %%
import pandas as pd

df = pd.read_csv("../data/raw/dataset-delevery.csv")

# %%
df.columns
# Out:
# Index(['Order_ID', 'Distance_km', 'Weather', 'Traffic_Level', 'Time_of_Day',
#        'Vehicle_Type', 'Preparation_Time_min', 'Courier_Experience_yrs',
#        'Delivery_Time_min'],
#       dtype='str')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.head(10)
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
# 5       679        19.40   Clear           Low     Evening      Scooter
# 6       627         9.52   Clear           Low         NaN         Bike
# 7       514        17.39   Clear        Medium     Evening      Scooter
# 8       860         1.78   Snowy           Low     Evening          Car
# 9       137        10.62   Foggy           Low     Evening      Scooter
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# ...

# %% [markdown]
# -  <H4> Nume </H4>
# 'Order_ID', 'Distance_km',
#         'Preparation_Time_min', 'Courier_Experience_yrs',
#        'Delivery_Time_min'
# -   <H4> Categorie </H4>  'Weather', 'Traffic_Level', 'Time_of_Day',
#        'Vehicle_Type'

# %%
df.dtypes
# Out:
# Order_ID                    int64
# Distance_km               float64
# Weather                       str
# Traffic_Level                 str
# Time_of_Day                   str
# Vehicle_Type                  str
# Preparation_Time_min        int64
# Courier_Experience_yrs    float64
# Delivery_Time_min           int64
# dtype: object

# %%
help(pd.Series.describe)
# Out:
# Help on function describe in module pandas.core.generic:
#
# describe(self, percentiles=None, include=None, exclude=None) -> 'Self'
#     Generate descriptive statistics.
#
#     Descriptive statistics include those that summarize the central
#     tendency, dispersion and shape of a
#     dataset's distribution, excluding ``NaN`` values.
#
#     Analyzes both numeric and object series, as well
#     as ``DataFrame`` column sets of mixed data types. The output
#     will vary depending on what is provided. Refer to the notes
#     below for more detail.
#
#     Parameters
#     ----------
#     percentiles : list-like of numbers, optional
#         The percentiles to include in the output. All should
#         fall between 0 and 1. The default, ``None``, will automatically
#         return the 25th, 50th, and 75th percentiles.
#     include : 'all', list-like of dtypes or None (default), optional
#         A white list of data types to include in the result. Ignored
# ...

# %%
df.describe()
# Out:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  1000.000000  1000.000000           1000.000000              970.000000
# mean    500.500000    10.059970             16.982000                4.579381
# std     288.819436     5.696656              7.204553                2.914394
# min       1.000000     0.590000              5.000000                0.000000
# 25%     250.750000     5.105000             11.000000                2.000000
# 50%     500.500000    10.190000             17.000000                5.000000
# 75%     750.250000    15.017500             23.000000                7.000000
# max    1000.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count        1000.000000
# mean           56.732000
# std            22.070915
# min             8.000000
# 25%            41.000000
# 50%            55.500000
# 75%            71.000000
# max           153.000000

# %%
#  Duplicates check
# subset tekes the column as reerence to identify the duplicates 
duplicate_count = df.duplicated(subset=['Order_ID']).sum()
print(f"Total Duplicate Orders: {duplicate_count}")
print(f"Duplicate rows: {df.duplicated().sum()}")
# Check for Nulls
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Total Duplicate Orders: 0
# Duplicate rows: 0
# Missing values per column:
# Order_ID                   0
# Distance_km                0
# Weather                   30
# Traffic_Level             30
# Time_of_Day               30
# Vehicle_Type               0
# Preparation_Time_min       0
# Courier_Experience_yrs    30
# Delivery_Time_min          0
# dtype: int64

# %%
# as a perentage 
(df.isnull().sum()/len(df)*100).round(2)
# Out:
# Order_ID                  0.0
# Distance_km               0.0
# Weather                   3.0
# Traffic_Level             3.0
# Time_of_Day               3.0
# Vehicle_Type              0.0
# Preparation_Time_min      0.0
# Courier_Experience_yrs    3.0
# Delivery_Time_min         0.0
# dtype: float64

# %%
df.drop(columns={'Order_ID'},inplace=True)

# %%
for i in ['Weather', 'Traffic_Level', 'Time_of_Day', 'Vehicle_Type']:
    print(i, df[i].unique())
# Out:
# Weather <StringArray>
# ['Windy', 'Clear', 'Foggy', 'Rainy', 'Snowy', nan]
# Length: 6, dtype: str
# Traffic_Level <StringArray>
# ['Low', 'Medium', 'High', nan]
# Length: 4, dtype: str
# Time_of_Day <StringArray>
# ['Afternoon', 'Evening', 'Night', 'Morning', nan]
# Length: 5, dtype: str
# Vehicle_Type <StringArray>
# ['Scooter', 'Bike', 'Car']
# Length: 3, dtype: str

# %%
column_with_missing_in_all_4_columns = df[df['Time_of_Day'].isna() | df['Traffic_Level'].isna() | df['Weather'].isna() | df['Courier_Experience_yrs'].isna()]
column_with_missing_in_all_4_columns

# I need to deside what to do for the meessing values
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 6           9.52   Clear           Low         NaN         Bike
# 14          2.80   Clear          High     Morning      Scooter
# 24         11.20   Clear        Medium     Morning         Bike
# 42          0.99     NaN        Medium     Evening         Bike
# 71          4.17     NaN           Low     Evening      Scooter
# ..           ...     ...           ...         ...          ...
# 974        11.68   Clear           NaN   Afternoon      Scooter
# 976         8.96   Snowy           NaN     Morning          Car
# 987         7.44   Rainy           Low     Evening         Bike
# 988        14.39   Rainy        Medium     Morning      Scooter
# 989         6.07     NaN           Low   Afternoon         Bike
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 6                      12                     1.0                 49
# ...

# %%
## Destrebution variable cible
from math import sqrt
import matplotlib.pyplot as plt

# Number of data points
n = len(df)
# Rule of thumb for bins
bins = int(sqrt(n))
# plt.hist(data=)
#  to choose the bins bins = int(sqrt(n)), n the number of data point
df['Delivery_Time_min'].hist(bins=bins)
skew = df['Delivery_Time_min'].skew()
plt.title('Delevery time min destribution ' + f'Skew calculatioon {skew:.2f}  ')
plt.show()

# > 1 or < -1 → consider log-transform
# import numpy as np 
# df['Delivery_Time_min'] = np.log(df['Delivery_Time_min'])
# If skew > 1, apply: y = np.log1p(df["Delivery_Time_min"]) and remember to expm1() predictions later.

# %%
num_colums = ["Distance_km","Preparation_Time_min","Courier_Experience_yrs"]


df[num_colums].hist(bins=bins)
plt.tight_layout()
plt.show()

# %%
df[["Delivery_Time_min"]].boxplot()
plt.show()

# %%
df[df['Delivery_Time_min']> 120]

## check if there is a pattern in the outliers to decide if I can delete them or replace them or only let them as they are.
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 29         18.05   Clear        Medium     Evening      Scooter
# 127        18.97   Clear           Low     Evening          Car
# 379        18.46   Clear           NaN         NaN      Scooter
# 452        15.64   Rainy           Low         NaN         Bike
# 784        14.83   Rainy           Low     Morning          Car
# 924        17.81   Windy          High     Evening         Bike
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 29                     10                     7.0                123
# 127                    25                     4.0                141
# 379                    29                     1.0                153
# 452                    20                     4.0                141
# 784                    19                     4.0                126
# 924                    21                     4.0                122

# %%
## Num columns > "Distance_km","Preparation_Time_min","Courier_Experience_yrs"

df[num_colums].boxplot()
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                         Distance_km  Preparation_Time_min  \
# Distance_km                1.000000             -0.009037
# Preparation_Time_min      -0.009037              1.000000
# Courier_Experience_yrs    -0.007842             -0.030830
# Delivery_Time_min          0.780998              0.307350
#
#                         Courier_Experience_yrs  Delivery_Time_min
# Distance_km                          -0.007842           0.780998
# Preparation_Time_min                 -0.030830           0.307350
# Courier_Experience_yrs                1.000000          -0.090433
# Delivery_Time_min                    -0.090433           1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True),annot=True )
plt.title("Correlation between the num values")
plt.show()

# %%
import matplotlib.pyplot as plt

# The primary way to see the linear relationship
sns.regplot(data=df, x='Distance_km', y='Delivery_Time_min', 
            scatter_kws={'alpha':0.5}, line_kws={'color':'red'})

plt.title('Impact of Distance on Delivery Time')
plt.show()

# %%
sns.jointplot(data=df, x='Distance_km', y='Delivery_Time_min', kind='reg',line_kws={'color':'red'})
plt.show()

# %%
sns.lmplot(data=df, x='Distance_km', y='Delivery_Time_min', hue='Traffic_Level')
plt.title('Distance vs Time by Traffic Level')
plt.show()

# %% [markdown]
# ## Contexte du projet
# Tu es un data scientist junior embauché par une entreprise de logistique et de livraison.
#
# Ton projet consiste à développer un modèle de Machine Learning capable de prédire le temps total d’une livraison, depuis la commande jusqu’à la réception.
#
# ### L’objectif est de permettre à l’entreprise :
#
# - d’anticiper les retards
# - d’informer les clients en temps réel
# - d’optimiser l’organisation des tournées
#
# Le modèle doit prédire <Strong>la variable DeliveryTime(le temps total de livraison) </Strong>, en tenant compte de plusieurs facteurs :
#
# - -> Distance_km : distance entre le restaurant et l’adresse de livraison
# - -> Traffic_Level : niveau de trafic
# - -> Vehicle_Type : type de véhicule utilisé
# - -> Time of Day : heure de la journée
# - -> Courier Experience : expérience du livreur
# - -> Weather : conditions meteo
# - -> Preparation time : temps de préparation de la commande
#
# #### Situation actuelle :
#   Les estimations de temps de livraison sont encore faites manuellement
# Pas de modèle de prédiction fiable ni de suivi des expérimentations
# Les retards fréquents créent une insatisfaction client
# L’équipe souhaite une preuve de concept fiable et automatisée avant déploiement.
#
#
# ### Votre Mission
# Analyse et Exploration des Données
# Heatmap de corrélation des variables numériques
# Countplots pour visualiser la distribution des variables catégorielles
# Boxplots pour analyser la relation entre la cible et les variables catégorielles (ex : trafic vs temps de livraison)
# Analyse de la distribution de la variable cible.
# Ces visualisations serviront à identifier les variables les plus explicatives avant la modélisation.
#
# Prétraitement (StandardScaler pour numérique, OneHotEncoder pour catégoriel)
# Sélection de features (SelectKBest)
# -Utiliser le test statistique f_regression
#
# Modélisation avec GridSearchCV (obligatoire)
# Choisir deux modèles de régression (RandomForestRegressor, SVR)
# Définir un grid d’hyperparamètres pour chaque modèle
# Utiliser GridSearchCV avec validation croisée pour trouver la meilleure combinaison selon la métrique MAE (Mean Absolute Error)
# Évaluer le modèle sélectionné avec MAE et R² sur le jeu de test
# Justifier le choix du modèle final en fonction de ses performances
# Bonus : Pipeline sklearn
# Créer un pipeline sklearn intégrant :
#
# Prétraitement (StandardScaler pour numérique, OneHotEncoder pour catégoriel)
# Sélection de features (SelectKBest)
# Modélisation (un des modèles testés dans GridSearchCV)
# Pipeline permet d’automatiser le flux de traitement et d’éviter les fuites de données
#
# Tests Automatisés
# Vérification du format et des dimensions des données
# Vérification que la MAE maximale ne dépasse pas un seuil défini
# Bonus : Intégration Continue avec GitHub Actions
# Configure une GitHub Action pour que les tests soient exécutés automatiquement à chaque push .
# Cela garantit que le code reste toujours fonctionnel.
#
# Exemple de fichier .github/workflows/python-tests.yml:
# ''''
# name: Run Unit Tests
# on:
#   push:
#     branches: [ main ]
# jobs:
#   test:
#     runs-on: ubuntu-latest
#     steps:
# name: Checkout du code
#         uses: actions/checkout@v4
# name: Installer Python
#         uses: actions/setup-python@v5
#         with:
#           python-version: '3.11'
# name: Installer les dépendances
#         run: |
#           python -m pip install --upgrade pip
#           pip install -r requirements.txt
#           pip install pytest joblib scikit-learn pandas
# name: Exécuter les tests
#         run: pytest -v
#         ''''
# Fonctionnement :
#
# À chaque push sur la branche main, GitHub déclenche ce workflow.
# Il installe l’environnement Python et les dépendances.
# Il exécute automatiquement les tests unitaires.
# Si un test échoue, GitHub affiche une alerte rouge dans la section Actions.

# %%
# why using the boxplot to see the relation between the target and the categoriels ? 
# how  to add all the other columns and how to interpret them the relation between them and the target ?

# %%
sns.boxplot(x="Traffic_Level", y="Delivery_Time_min", data=df)
sns.stripplot(x="Traffic_Level", y="Delivery_Time_min", data=df, color="red", alpha=0.3)

# we can see that the delevery time is increased with the trafic level when the traffic level is getting higher the time increases.
# allso the median is raised --> thats a Strong signal its a strong predector
# Out:
# <Axes: xlabel='Traffic_Level', ylabel='Delivery_Time_min'>

# %%
sns.boxplot(x="Weather", y="Delivery_Time_min", data=df)
sns.stripplot(x="Weather", y="Delivery_Time_min", data=df, color="red", alpha=0.3)

#  rainy , foggy, and snowy show more delevery time weak sinal but worth keeping
# Out:
# <Axes: xlabel='Weather', ylabel='Delivery_Time_min'>

# %%
sns.boxplot(x="Vehicle_Type", y="Delivery_Time_min", data=df)
sns.stripplot(x="Vehicle_Type", y="Delivery_Time_min", data=df, color="red", alpha=0.3)
# Out:
# <Axes: xlabel='Vehicle_Type', ylabel='Delivery_Time_min'>

# %%
sns.boxplot(x="Time_of_Day", y="Delivery_Time_min", data=df)
sns.stripplot(x="Time_of_Day", y="Delivery_Time_min", data=df, color="red", alpha=0.3)
# Out:
# <Axes: xlabel='Time_of_Day', ylabel='Delivery_Time_min'>

# %% [markdown]
# ### From the Numerical the mot importent is the destance in the categorial the most importet is the trafic level

# %%
## Standar scale and Encoding 
## what will happen if we didnt fill the missing values for the encoding or the others .. ? 

"""
Most standard ML libraries, especially Scikit-Learn,
 will throw a ValueError during 
the .fit() process if they encounter a missing value.
"""

# %%
mask = df[['Weather', 'Traffic_Level', 'Time_of_Day', 'Courier_Experience_yrs']].isna().any(axis=1)

df[mask]
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 6           9.52   Clear           Low         NaN         Bike
# 14          2.80   Clear          High     Morning      Scooter
# 24         11.20   Clear        Medium     Morning         Bike
# 42          0.99     NaN        Medium     Evening         Bike
# 71          4.17     NaN           Low     Evening      Scooter
# ..           ...     ...           ...         ...          ...
# 974        11.68   Clear           NaN   Afternoon      Scooter
# 976         8.96   Snowy           NaN     Morning          Car
# 987         7.44   Rainy           Low     Evening         Bike
# 988        14.39   Rainy        Medium     Morning      Scooter
# 989         6.07     NaN           Low   Afternoon         Bike
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 6                      12                     1.0                 49
# ...

# %%
trap_cols = ['Weather', 'Traffic_Level', 'Time_of_Day', 'Courier_Experience_yrs']

df['null_count'] = df[trap_cols].isnull().sum(axis=1)

print(df['null_count'])
#  it count for each line the  number of nan nun values then we the value count do calculate the sum of them 

# Summary of the pattern
print(df['null_count'].value_counts())


# 0 883 with 0 nan, 114 with only 1 nan and 3 with 2 nan , so there is no row with 4 nan
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: null_count, Length: 1000, dtype: int64
# null_count
# 0    883
# 1    114
# 2      3
# Name: count, dtype: int64

# %%
# replace categorical wth the mode the mode gives as a serie thats way we use the index 0 and the mean for the experience years column

for i in  ['Weather', 'Traffic_Level', 'Time_of_Day']:
    replace_value = df[i].mode()[0]
    df[i]= df[i].fillna(value=replace_value)



median_value = df['Courier_Experience_yrs'].mode()[0]
df['Courier_Experience_yrs']= df['Courier_Experience_yrs'].fillna(value=median_value)

# %%
df.drop(columns={'null_count'},inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with subplots for our numerical columns
cols_to_plot = ['Distance_km', 'Preparation_Time_min', 'Courier_Experience_yrs', 'Delivery_Time_min']
plt.figure(figsize=(16, 4))

for i, col in enumerate(cols_to_plot):
    plt.subplot(1, 4, i+1)
    sns.boxplot(data=df, y=col, color='skyblue')
    plt.title(f'Spread of {col}')

plt.tight_layout()
plt.show()

# %%
Q1 = df['Delivery_Time_min'].quantile(0.25)
Q3 = df['Delivery_Time_min'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Delivery_Time_min'] < lower_bound) | (df['Delivery_Time_min'] > upper_bound)]
print(f"Number of outliers in Delivery Time: {len(outliers)}")
print(f"Anything above {upper_bound:.2f} mins is statistically an outlier.")
# Out:
# Number of outliers in Delivery Time: 6
# Anything above 116.00 mins is statistically an outlier.

# %%
# check if the the data is 

cols = ['Weather', 'Traffic_Level', 'Vehicle_Type']
# we only worry if a category drops below 2-3%.
for i in cols:
    print(i, df[i].value_counts(normalize=True)*100)
# Out:
# Weather Weather
# Clear    50.0
# Rainy    20.4
# Foggy    10.3
# Snowy     9.7
# Windy     9.6
# Name: proportion, dtype: float64
# Traffic_Level Traffic_Level
# Medium    42.0
# Low       38.3
# High      19.7
# Name: proportion, dtype: float64
# Vehicle_Type Vehicle_Type
# Bike       50.3
# Scooter    30.2
# Car        19.5
# Name: proportion, dtype: float64

# %%
outliers = df[df['Delivery_Time_min'] > 116]
display(outliers)
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 29         18.05   Clear        Medium     Evening      Scooter
# 127        18.97   Clear           Low     Evening          Car
# 379        18.46   Clear        Medium     Morning      Scooter
# 452        15.64   Rainy           Low     Morning         Bike
# 784        14.83   Rainy           Low     Morning          Car
# 924        17.81   Windy          High     Evening         Bike
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 29                     10                     7.0                123
# 127                    25                     4.0                141
# 379                    29                     1.0                153
# 452                    20                     4.0                141
# 784                    19                     4.0                126
# 924                    21                     4.0                122

# %%
# Next step replacing the nan @@ strategic imputation mean, mode or median depanding on the case 
# for the outliers I will keep them based on the search I did they are logical for the lang distance delevery the model need to learn about them

# %%
# skewness of the target 

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
sns.histplot(df['Delivery_Time_min'], kde=True)
plt.title(f"Target Distribution (Skew: {df['Delivery_Time_min'].skew():.2f})")
plt.show()

# %%
sns.pairplot(df)

# %%
data=df[['Distance_km', 'Preparation_Time_min', 'Courier_Experience_yrs', 'Delivery_Time_min']]
data.corr()
# Out:
#                         Distance_km  Preparation_Time_min  \
# Distance_km                1.000000             -0.009037
# Preparation_Time_min      -0.009037              1.000000
# Courier_Experience_yrs    -0.007091             -0.031922
# Delivery_Time_min          0.780998              0.307350
#
#                         Courier_Experience_yrs  Delivery_Time_min
# Distance_km                          -0.007091           0.780998
# Preparation_Time_min                 -0.031922           0.307350
# Courier_Experience_yrs                1.000000          -0.088996
# Delivery_Time_min                    -0.088996           1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# We only correlate numbers
numerical_cols = ['Distance_km', 'Preparation_Time_min', 'Courier_Experience_yrs', 'Delivery_Time_min']

plt.figure(figsize=(10, 6))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Matrix: Identifying the Heavy Hitters")
plt.show()

# %%
# Mapping Traffic Level
traffic_mapping = {'Low': 1, 'Medium': 2, 'High': 3, 'Jam': 4}
df['Traffic_Level'] = df['Traffic_Level'].map(traffic_mapping)

# Mapping Time of Day
time_mapping = {'Morning': 1, 'Afternoon': 2, 'Evening': 3, 'Night': 4}
df['Time_of_Day'] = df['Time_of_Day'].map(time_mapping)

# %%
# By using drop_first=True in your delivery time model:

# You have fewer columns, which makes the model faster.

# You avoid mathematical errors caused by redundant data.

# Your results are easier to interpret because every weather condition is compared to one "default" weather type.

categorical_col = ['Weather', 'Traffic_Level', 'Time_of_Day', 'Vehicle_Type']
df_encoded = pd.get_dummies(df, columns=categorical_col, drop_first=True)
